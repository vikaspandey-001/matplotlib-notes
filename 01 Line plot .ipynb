# %% [markdown]
# # Line Plot

# %%
import matplotlib.pyplot as plt
x=[11,15,50,26]
y=[2,6,10,14]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[11,15,50,26]
y=[2,6,10,14]
plt.plot(x,y,color='r')
plt.show()
